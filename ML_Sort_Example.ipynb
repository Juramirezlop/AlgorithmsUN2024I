# %% [markdown]
# <a href="https://colab.research.google.com/github/Juramirezlop/AlgorithmsUN2024I/blob/main/ML_Sort_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learning to sort with a Neural Network (MLPRegressor)

# %%
import random as rnd
import numpy as np

n=10
Nexamples=1000

X =[]
y =[]
for j in range(Nexamples):
  list1 = list(range(n))
  rnd.shuffle(list1)
  X.append(np.array(list1))
  best = max(list1)
  y.append(np.array(best))

# %%
import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y]})
data
# Out:
#                                   X  y
# 0    [4, 5, 3, 0, 9, 1, 7, 6, 8, 2]  9
# 1    [4, 8, 9, 3, 2, 6, 5, 7, 0, 1]  9
# 2    [8, 2, 1, 0, 7, 9, 6, 3, 4, 5]  9
# 3    [2, 0, 9, 6, 5, 8, 1, 4, 3, 7]  9
# 4    [1, 9, 6, 3, 8, 5, 4, 7, 2, 0]  9
# ..                              ... ..
# 995  [4, 8, 0, 9, 5, 2, 1, 3, 6, 7]  9
# 996  [3, 8, 0, 6, 1, 7, 5, 4, 9, 2]  9
# 997  [3, 7, 0, 8, 9, 2, 1, 5, 4, 6]  9
# 998  [3, 1, 8, 9, 2, 0, 6, 7, 5, 4]  9
# 999  [8, 4, 0, 5, 2, 9, 3, 1, 7, 6]  9
#
# [1000 rows x 2 columns]

# %%
from sklearn.neural_network import MLPRegressor
model = MLPRegressor(hidden_layer_sizes=(100,50,20),random_state=1, max_iter=1000, activation='logistic').fit(X,y)
y_pred =model.predict(X)

import matplotlib.pyplot as plt
plt.plot(model.loss_curve_)
plt.show()

# %%
import pandas as pd
y_p = pd.DataFrame({'y_pred': [round(pred,3) for pred in y_pred]})
y_p
# Out:
#      y_pred
# 0      8.96
# 1      8.96
# 2      8.96
# 3      8.96
# 4      8.96
# ..      ...
# 995    8.96
# 996    8.96
# 997    8.96
# 998    8.96
# 999    8.96
#
# [1000 rows x 1 columns]

# %%
import random as rnd
import numpy as np

n=10
Nexamples=1000

X =[]
y =[]
for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

y_pred = model.predict(X)

import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
#                                   X  y  y_pred
# 0    [4, 0, 9, 2, 1, 3, 6, 7, 5, 8]  9       9
# 1    [2, 5, 6, 0, 8, 9, 7, 3, 4, 1]  9       9
# 2    [4, 6, 5, 2, 8, 7, 9, 1, 0, 3]  9       9
# 3    [6, 0, 3, 7, 8, 2, 4, 5, 9, 1]  9       9
# 4    [9, 6, 3, 4, 8, 1, 7, 0, 2, 5]  9       9
# ..                              ... ..     ...
# 995  [9, 2, 3, 7, 0, 5, 6, 1, 8, 4]  9       9
# 996  [9, 7, 0, 4, 1, 8, 2, 6, 3, 5]  9       9
# 997  [2, 1, 4, 0, 5, 8, 7, 3, 9, 6]  9       9
# 998  [2, 1, 5, 6, 4, 8, 0, 7, 3, 9]  9       9
# 999  [9, 6, 3, 5, 2, 4, 1, 7, 0, 8]  9       9
#
# [1000 rows x 3 columns]

# %%
import random as rnd
import numpy as np

n=10
Nexamples=1000

X =[]
y =[]
for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

y_pred = model.predict(X)

import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
#                                        X   y  y_pred
# 0    [2, 16, 0, 8, 12, 6, 14, 18, 10, 4]  18       9
# 1    [16, 18, 12, 2, 10, 8, 6, 14, 4, 0]  18       9
# 2    [16, 8, 6, 10, 0, 12, 4, 14, 2, 18]  18       9
# 3    [12, 10, 16, 18, 14, 6, 2, 8, 4, 0]  18       9
# 4    [0, 8, 6, 10, 18, 16, 14, 2, 4, 12]  18       9
# ..                                   ...  ..     ...
# 995  [2, 4, 12, 8, 14, 0, 16, 6, 18, 10]  18       9
# 996  [16, 18, 8, 14, 0, 6, 4, 12, 10, 2]  18       9
# 997  [12, 6, 14, 4, 16, 8, 0, 10, 2, 18]  18       9
# 998  [2, 16, 12, 8, 18, 6, 0, 10, 14, 4]  18       9
# 999  [8, 0, 6, 18, 14, 12, 4, 2, 16, 10]  18       9
#
# [1000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=1000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

model = MLPRegressor(hidden_layer_sizes=(100,50,20), max_iter=1000, activation='tanh').fit(X,y)
y_pred =model.predict(X)


plt.plot(model.loss_curve_)
plt.show()

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 1.000
#                                         X   y  y_pred
# 0          [3, 9, 8, 5, 0, 4, 6, 2, 1, 7]   9       9
# 1          [8, 6, 7, 9, 5, 3, 2, 0, 1, 4]   9       9
# 2          [5, 3, 1, 9, 0, 4, 7, 2, 8, 6]   9       9
# 3          [5, 1, 8, 7, 9, 4, 6, 2, 0, 3]   9       9
# 4          [6, 7, 3, 2, 8, 1, 5, 0, 4, 9]   9       9
# ...                                   ...  ..     ...
# 1995  [10, 2, 14, 4, 18, 8, 0, 6, 16, 12]  18      18
# 1996  [14, 10, 0, 18, 12, 6, 16, 4, 8, 2]  18      18
# 1997  [0, 2, 12, 14, 18, 10, 8, 6, 4, 16]  18      18
# 1998  [6, 16, 12, 0, 14, 4, 2, 8, 18, 10]  18      18
# 1999  [2, 8, 10, 4, 16, 14, 0, 18, 6, 12]  18      18
#
# [2000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=1000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

model = MLPRegressor(hidden_layer_sizes=(100,50,20), max_iter=1000, activation='relu').fit(X,y)
y_pred =model.predict(X)


plt.plot(model.loss_curve_)
plt.show()

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.999
#                                         X   y  y_pred
# 0          [4, 8, 7, 0, 3, 6, 2, 9, 5, 1]   9       9
# 1          [0, 2, 1, 8, 7, 3, 6, 9, 5, 4]   9       9
# 2          [9, 7, 3, 6, 5, 8, 1, 0, 2, 4]   9       9
# 3          [9, 7, 8, 5, 2, 4, 1, 3, 6, 0]   9       9
# 4          [6, 5, 4, 7, 2, 9, 1, 8, 3, 0]   9       9
# ...                                   ...  ..     ...
# 1995  [16, 18, 6, 4, 12, 14, 0, 8, 10, 2]  18      18
# 1996  [18, 2, 8, 16, 10, 0, 14, 4, 6, 12]  18      18
# 1997  [18, 14, 16, 6, 10, 8, 12, 0, 2, 4]  18      18
# 1998  [18, 4, 8, 16, 2, 12, 14, 10, 6, 0]  18      18
# 1999  [18, 8, 16, 4, 14, 10, 2, 0, 6, 12]  18      18
#
# [2000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.999
#                                          X   y  y_pred
# 0           [6, 1, 8, 7, 0, 9, 5, 2, 3, 4]   9       9
# 1           [7, 2, 8, 5, 0, 3, 1, 4, 9, 6]   9       9
# 2           [4, 1, 6, 5, 9, 0, 8, 2, 3, 7]   9       9
# 3           [6, 1, 3, 2, 4, 7, 8, 0, 9, 5]   9       9
# 4           [1, 2, 0, 7, 3, 6, 9, 5, 4, 8]   9       9
# ...                                    ...  ..     ...
# 19995  [14, 12, 0, 16, 8, 6, 4, 18, 10, 2]  18      18
# 19996  [10, 16, 4, 0, 8, 14, 2, 6, 18, 12]  18      18
# 19997  [6, 8, 12, 16, 14, 18, 2, 10, 0, 4]  18      18
# 19998  [8, 10, 14, 12, 4, 2, 16, 0, 18, 6]  18      18
# 19999  [12, 18, 6, 8, 0, 14, 16, 4, 2, 10]  18      18
#
# [20000 rows x 3 columns]

# %% [markdown]
# # Learning to sort with a Classification and Regression Tree (CART)
#
# * https://towardsdatascience.com/cart-classification-and-regression-trees-for-clean-but-powerful-models-cc89e60b7a85
#
# * https://spotle.ai/feeddetails/Classification-and-Regression-Tree-CART-with-Python/3644
#
# ### Visualize a Decision Tree in 4 Ways with Scikit-Learn and Python
#
# * https://towardsdatascience.com/cart-classification-and-regression-trees-for-clean-but-powerful-models-cc89e60b7a85

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

model = DecisionTreeRegressor(max_leaf_nodes = 15).fit(X,y)

# %%
import random as rnd
import numpy as np

n=10
Nexamples=10000

X =[]
y =[]
for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))



y_pred = model.predict(X)

import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
#                                    X  y  y_pred
# 0     [0, 1, 2, 9, 6, 3, 7, 5, 8, 4]  9       9
# 1     [6, 0, 3, 8, 1, 2, 9, 4, 7, 5]  9       9
# 2     [4, 8, 2, 5, 1, 6, 9, 7, 0, 3]  9       9
# 3     [3, 2, 0, 1, 6, 9, 5, 7, 8, 4]  9       9
# 4     [7, 3, 5, 8, 0, 9, 2, 6, 4, 1]  9       9
# ...                              ... ..     ...
# 9995  [8, 0, 5, 1, 3, 2, 9, 6, 7, 4]  9       9
# 9996  [6, 4, 9, 7, 0, 3, 2, 5, 1, 8]  9       9
# 9997  [0, 9, 7, 8, 6, 4, 2, 1, 3, 5]  9       9
# 9998  [6, 2, 3, 0, 9, 7, 5, 8, 1, 4]  9       9
# 9999  [4, 0, 1, 9, 7, 6, 8, 5, 3, 2]  9       9
#
# [10000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- value: [9.00]

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

model = DecisionTreeRegressor(max_leaf_nodes = 50).fit(X,y)

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    list1 = list(range(n))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

for j in range(Nexamples):
    list1 = list(2*np.array(range(n)))
    rnd.shuffle(list1)
    X.append(np.array(list1))
    maxim = max(list1)
    y.append(np.array(maxim))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.999
#                                          X   y  y_pred
# 0           [0, 4, 3, 9, 1, 7, 8, 6, 2, 5]   9       9
# 1           [4, 3, 7, 8, 0, 6, 1, 9, 5, 2]   9       9
# 2           [5, 8, 6, 9, 0, 3, 7, 2, 4, 1]   9       9
# 3           [6, 7, 1, 9, 4, 3, 2, 8, 0, 5]   9       9
# 4           [8, 5, 6, 1, 7, 4, 9, 3, 0, 2]   9       9
# ...                                    ...  ..     ...
# 19995  [8, 2, 4, 10, 12, 6, 0, 14, 16, 18]  18      18
# 19996  [4, 6, 0, 2, 10, 12, 8, 16, 18, 14]  18      18
# 19997  [10, 16, 2, 8, 4, 12, 6, 18, 14, 0]  18      18
# 19998  [2, 16, 12, 6, 14, 0, 18, 10, 4, 8]  18      18
# 19999  [6, 14, 16, 10, 12, 0, 4, 2, 18, 8]  18      18
#
# [20000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- feature_0 <= 9.50
# |   |--- feature_8 <= 9.50
# |   |   |--- feature_1 <= 9.50
# |   |   |   |--- feature_4 <= 9.50
# |   |   |   |   |--- feature_6 <= 9.50
# |   |   |   |   |   |--- feature_7 <= 11.50
# |   |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |   |--- feature_7 >  11.50
# |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |--- feature_6 >  9.50
# |   |   |   |   |   |--- value: [18.00]
# |   |   |   |--- feature_4 >  9.50
# |   |   |   |   |--- value: [18.00]
# |   |   |--- feature_1 >  9.50
# |   |   |   |--- value: [18.00]
# |   |--- feature_8 >  9.50
# |   |   |--- value: [18.00]
# |--- feature_0 >  9.50
# |   |--- value: [18.00]

# %%
import graphviz # for plotting decision tree graphs
from sklearn import tree

dot_data = tree.export_graphviz(model, out_file=None,
                                feature_names=names,
                                filled=True,
                                rotate=True,
                               )

graph = graphviz.Source(dot_data)

graph

# %%
from IPython.display import Image
from sklearn import tree
import matplotlib.image as mpimg
import pydotplus
import io
import matplotlib.pyplot as plt

import sys
str1 = "/usr/local/Cellar/graphviz/2.40.1_1/bin/"
sys.path.append(str1)

dot_data = io.StringIO()
tree.export_graphviz(model, out_file=dot_data, filled=True, feature_names = names )

# Draw graph
pydotplus.graph_from_dot_data(dot_data.getvalue()).write_png('dt.png')

plt.figure(figsize=(20, 20))
img = mpimg.imread('dt.png')
imgplot = plt.imshow(img)

plt.show()
